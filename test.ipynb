# %%
import pandas as pd

# %%
df = pd.read_excel('Suivi_Alimentation.xlsx')

# %%
df.head()
# Out:
#    alim_grp_code  alim_ssgrp_code  alim_ssssgrp_code  \
# 0            2.0            201.0            20101.0
# 1            2.0            201.0            20101.0
# 2            2.0            201.0            20101.0
# 3            2.0            201.0            20101.0
# 4            2.0            201.0            20101.0
#
#                                alim_grp_nom_fr alim_ssgrp_nom_fr  \
# 0  fruits, légumes, légumineuses et oléagineux           légumes
# 1  fruits, légumes, légumineuses et oléagineux           légumes
# 2  fruits, légumes, légumineuses et oléagineux           légumes
# 3  fruits, légumes, légumineuses et oléagineux           légumes
# 4  fruits, légumes, légumineuses et oléagineux           légumes
#
#   alim_ssssgrp_nom_fr  alim_code                      alim_nom_fr  \
# 0        légumes crus    13004.0               Avocat, pulpe, cru
# 1        légumes crus    20004.0            Bette ou blette, crue
# 2        légumes crus    20009.0                    Carotte, crue
# 3        légumes crus    20010.0       Champignon, tout type, cru
# 4        légumes crus    20012.0  Salade ou chicorée frisée, crue
#
#   alim_nom_sci Energie, Règlement UE N° 1169/2011 (kJ/100 g)  ...  \
# 0          NaN                                           843  ...
# 1          NaN                                          68.3  ...
# 2          NaN                                           169  ...
# 3          NaN                                          91.2  ...
# 4          NaN                                             -  ...
#
#   Vitamine K1 (µg/100 g) Vitamine K2 (µg/100 g) Vitamine C (mg/100 g)  \
# 0                   14.5                      -                 < 0,5
# 1                  < 0,8                      -                  3.08
# 2                   2.96                      -                  2.05
# 3                      0                      -                   3.4
# 4                    298                      -                  18.5
#
#   Vitamine B1 ou Thiamine (mg/100 g) Vitamine B2 ou Riboflavine (mg/100 g)  \
# 0                              0.052                                 0.037
# 1                            < 0,015                                 0.015
# 2                              0.028                                < 0,01
# 3                              0.084                                  0.42
# 4                               0.07                                 0.088
#
#   Vitamine B3 ou PP ou Niacine (mg/100 g)  \
# 0                                    1.56
# 1                                   < 0,1
# 2                                   < 0,1
# 3                                    4.55
# 4                                    0.45
#
#   Vitamine B5 ou Acide pantothénique (mg/100 g) Vitamine B6 (mg/100 g)  \
# 0                                          1.07                   0.17
# 1                                           0.2                  0.036
# 2                                           0.2                  0.093
# 3                                          1.75                  0.082
# 4                                          1.03                  0.063
#
#   Vitamine B9 ou Folates totaux (µg/100 g) Vitamine B12 (µg/100 g)
# 0                                     70.4                       0
# 1                                     24.7                       0
# 2                                     59.4                       0
# 3                                       29                       0
# 4                                      126                       0
#
# [5 rows x 76 columns]

# %%
import streamlit as st
import pandas as pd

# Titre de l'application
st.title("Créateur de Recettes")

# Champs pour entrer les informations de la recette
nom = st.text_input("Nom de la recette")
ingredients = st.text_area("Ingrédients (séparés par des virgules)")
instructions = st.text_area("Instructions")

# Bouton pour sauvegarder
if st.button("Sauvegarder la recette"):
    recette = {
        "Nom": nom,
        "Ingrédients": ingredients,
        "Instructions": instructions
    }
    try:
        # Charger ou créer un fichier Excel
        try:
            df = pd.read_excel("recettes.xlsx")
        except FileNotFoundError:
            df = pd.DataFrame(columns=["Nom", "Ingrédients", "Instructions"])
        
        # Ajouter la nouvelle recette
        df = df.append(recette, ignore_index=True)
        df.to_excel("recettes.xlsx", index=False)
        st.success(f"Recette '{nom}' sauvegardée avec succès !")
    except Exception as e:
        st.error(f"Erreur lors de la sauvegarde : {e}")
# Out:
# 2025-05-06 00:15:42.317
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/anaconda3/envs/INF551_env/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-05-06 00:15:42.318 Session state does not function when running a script without `streamlit run`
